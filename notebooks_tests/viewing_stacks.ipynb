# %%
import ipywidgets as widgets
import matplotlib.pyplot as plt
#import mpl_interactions.ipyplot as iplt
from nd2reader import ND2Reader
import pandas as pd
from IPython.display import display
import numpy as np
import sys
#sys.path.append('/home/m/Miguel.Atienza/celltracker')
#sys.path.append('/mnt/d/ubuntu/physhome/celltracker')
sys.path.append('/project/ag-moonraedler/MAtienza/pyama/')
#from celltracker.pipeline import Track
#from celltracker import functions
from tqdm import tqdm
import os
from skimage.io import imread
from notebook_viewer import viewers
#from src.img_op import background_correction, coarse_binarize_phc
#from src import tracking
# %matplotlib ipympl
# %load_ext autoreload
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_164/717457252.py in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 #import mpl_interactions.ipyplot as iplt
# ----> 4 from nd2reader import ND2Reader
#       5 import pandas as pd
#       6 from IPython.display import display
#
# ModuleNotFoundError: No module named 'nd2reader'

# %%
data_path = '/project/ag-moonraedler/Nathalie/2022-04-25/hek293t-25um-30um-pattern-trafo.nd2'
#data_path='/project/ag-moonraedler/MAtienza/Experiments/UNikon_230522/time_lapse001.nd2'

# %%
#%autoreload
viewer = viewers.StackViewer(data_path)
# Out:
# GridspecLayout(children=(Canvas(header_visible=False, layout=Layout(grid_area='widget001'), toolbar=Toolbar(to…

# %%
bf_channel=0

# %%
# %autoreload
segmentation_viewer = viewers.CellposeViewer(data_path, bf_channel)
# Out:
# GridspecLayout(children=(Canvas(header_visible=False, layout=Layout(grid_area='widget001'), toolbar=Toolbar(to…

# %%
mask = coarse_binarize_phc.binarize_frame(viewer.image)

# %%
plt.subplots()
plt.imshow(mask)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from skimage.measure import label

mask_labeled = label(mask, connectivity=1)

# %%
plt.subplots()
plt.imshow(mask_labeled)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df = pd.read_csv('/project/ag-moonraedler/MAtienza/pyama/tracking_data.csv')

# %%
plt.close('all')
dfp = df[df.id==60]
plt.plot(dfp.frame, dfp.fluorescence)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
